# %%
# 10*10*10 Cells
# test for greenfunction
# OpenMC inp maked by ryy

# %%
import openmc
import numpy as np
import openmc.model

import os
os.environ['OPENMC_CROSS_SECTIONS'] = '/home/ryy/beta/Data/mcnp_endfb70/cross_sections.xml' 
openmc.config.cross_sections = '/home/ryy/beta/Data/mcnp_endfb70/cross_sections.xml'
# Out:
# /home/ryy/anaconda3/envs/openmc-env/lib/python3.12/site-packages/numpy/_core/getlimits.py:551: UserWarning: Signature b'\x00\xd0\xcc\xcc\xcc\xcc\xcc\xcc\xfb\xbf\x00\x00\x00\x00\x00\x00' for <class 'numpy.longdouble'> does not match any known type: falling back to type probe function.
# This warnings indicates broken support for the dtype!
#   machar = _get_machar(dtype)

# %%
# Material
M1 = openmc.Material()
M1.add_nuclide('U235', 0.94, 'wo')
M1.add_nuclide('U235', 0.06, 'wo')
M1.set_density('g/cm3', 19)

materials = openmc.Materials()
materials += [M1]
materials.export_to_xml()

# %%
# Surface
x1=openmc.XPlane(x0=0)
x2=openmc.XPlane(x0=1)
x3=openmc.XPlane(x0=0, boundary_type = 'vacuum')
x4=openmc.XPlane(x0=10, boundary_type = 'vacuum')

y1=openmc.YPlane(y0=0)
y2=openmc.YPlane(y0=1)
y3=openmc.YPlane(y0=0, boundary_type = 'vacuum')
y4=openmc.YPlane(y0=10, boundary_type = 'vacuum')

z1=openmc.ZPlane(z0=0)
z2=openmc.ZPlane(z0=1)
z3=openmc.ZPlane(z0=0, boundary_type = 'vacuum')
z4=openmc.ZPlane(z0=10, boundary_type = 'vacuum')

# %%
#f_c=openmc.Cell(fill=M1,region=+x1 & -x2 & +y1 & -y2 & +z1 & -z2)
#n_c=openmc.Cell(fill=None,region=+x1 & -x2 & +y1 & -y2 & +z1 & -z2)
f_c=openmc.Cell(fill=M1)
n_c=openmc.Cell(fill=None)
f=openmc.Universe()
f.add_cell(f_c)
n=openmc.Universe()
n.add_cell(n_c)

outer_c=openmc.Cell(fill = None)
outer=openmc.Universe()
outer.add_cell(outer_c)

# %%
lattice=openmc.RectLattice()
lattice.lower_left=(0, 0, 0)
lattice.pitch=(1, 1, 1)
lattice.outer=outer
lattice.universes=[
        [[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n]],
        [[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f]],
        [[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n]],
        [[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f]],
        [[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n]],
        [[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f]],
        [[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n]],
        [[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f]],
        [[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n]],
        [[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f],[f, n, f, n, f, n, f, n, f, n],[n, f, n, f, n, f, n, f, n, f]]]

l_c=openmc.Cell(fill=lattice,region=+x3 & -x4 & +y3 & -y4 & +z3 & -z4)
root=openmc.Universe()
root.add_cell(l_c)

# %%
## Plot
##配置卡
## Geom
#geom = openmc.Geometry(root)
#geom.export_to_xml()
#plot_settings = openmc.Settings()
#plot_settings.run_mode = 'plot'
#plot_settings.export_to_xml()
#
#plot_xz = openmc.Plot(plot_id = 1)
#plot_xz.color_by = 'material'
#plot_xz.basis = 'xz'
#plot_xz.origin = (4.5, 3.5, 4.5)
#plot_xz.width = (15, 15)
#plot_xz.pixels = (1000, 1000)
#plot_xz.filename = 'pic-xz'
#
#plot_xy = openmc.Plot(plot_id = 2)
#plot_xy.basis = 'xy'
#plot_xy.color_by = 'material'
#plot_xy.origin = (4.5, 4.5, 4.5)
#plot_xy.width = (15, 15)
#plot_xy.pixels = (1000, 1000)
#plot_xy.filename = 'pic-xy'
#
#plots = openmc.Plots([plot_xz, plot_xy])
#plots.export_to_xml()
#openmc.plot_geometry(output=True)

# %%
# Setting
settings = openmc.Settings()
settings.batches = 115
settings.inactive = 15
settings.particles = 1000
settings.run_mode = 'eigenvalue'

source_location = (5.1, 5.1, 5.1)
point_source = openmc.stats.Point(xyz = source_location)
source = openmc.IndependentSource(space = point_source)
source.particle = 'neutron'

settings.source = source
settings.export_to_xml()

# %%
openmc.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
# ...
